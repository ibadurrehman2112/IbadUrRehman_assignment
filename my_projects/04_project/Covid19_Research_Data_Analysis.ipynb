# %%
#Importing Libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading Dataset
df=pd.read_csv('resources/covid_19_data.csv');

# %%
#Loading Dataset
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %% [markdown]
# #Understanding Data

# %%
df.shape
#there are 244284 rows and 8 columns
# Out:
# (306429, 8)

# %%
df.isnull().sum()
#below null values in columns
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     78100
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %%
df.info()
#below type of Data in the columns (int,object,float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  object
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.7+ MB

# %%
df.describe()
#below shows the descriptive statistics of Data like mean, std deviation, min and max values present in the dataset
# Out:
#                  SNo     Confirmed         Deaths     Recovered
# count  306429.000000  3.064290e+05  306429.000000  3.064290e+05
# mean   153215.000000  8.567091e+04    2036.403268  5.042029e+04
# std     88458.577156  2.775516e+05    6410.938048  2.015124e+05
# min         1.000000 -3.028440e+05    -178.000000 -8.544050e+05
# 25%     76608.000000  1.042000e+03      13.000000  1.100000e+01
# 50%    153215.000000  1.037500e+04     192.000000  1.751000e+03
# 75%    229822.000000  5.075200e+04    1322.000000  2.027000e+04
# max    306429.000000  5.863138e+06  112385.000000  6.399531e+06

# %%
df.keys()
#Displaying all the columns names present in the dataset
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df.columns
#different code but same as above displaying all columns names present in dataset
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df.nunique()
#The nunique() function is used to count distinct observation over requested axis, it returns series with number of distinct obervations.
# Out:
# SNo                306429
# ObservationDate       494
# Province/State        737
# Country/Region        229
# Last Update          1905
# Confirmed          107146
# Deaths              20089
# Recovered           74541
# dtype: int64

# %%
df.tail()
#displaying last 5 rows of dataset
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 306424  2021-05-30 04:20:55   102641.0  2335.0    95289.0
# 306425  2021-05-30 04:20:55    29147.0   245.0        0.0
# 306426  2021-05-30 04:20:55     1364.0     1.0     1324.0
# 306427  2021-05-30 04:20:55    87550.0  1738.0    83790.0
# 306428  2021-05-30 04:20:55   391559.0  4252.0        0.0

# %%
#df=df.iloc[:]
#df
#this function iloc select all the rows except the last row

# %%
df=pd.read_csv('resources/covid_19_data.csv');

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df.tail()
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 306424  2021-05-30 04:20:55   102641.0  2335.0    95289.0
# 306425  2021-05-30 04:20:55    29147.0   245.0        0.0
# 306426  2021-05-30 04:20:55     1364.0     1.0     1324.0
# 306427  2021-05-30 04:20:55    87550.0  1738.0    83790.0
# 306428  2021-05-30 04:20:55   391559.0  4252.0        0.0

# %%
df
#This is the Dataset we are going to work on
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df['Confirmed'].sum(axis=0)
#The Total number of confirmed cases in all over the World is 26252051758.0
# Out:
# 26252051758.0

# %%
df['Recovered'].sum(axis=0)
##The Total number of Recovered cases in all over the World is 15450237912.0
# Out:
# 15450237912.0

# %%
df['Deaths'].sum(axis=0)
###The Total number of Death cases in all over the World is 624013017.0
# Out:
# 624013017.0

# %% [markdown]
# #Data Visualization

# %%
sns.pairplot(data=df)
#Scatter plots of all data using pairplot

# %%
cases_df = df.sum()
#Storing Total cases in cases dataframe
# Out:
# /tmp/ipykernel_257927/3085258123.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cases_df = df.sum()

# %%
cases_df
#Subset of the original dataset
# Out:
# SNo                                                      46949519235
# ObservationDate    01/22/202001/22/202001/22/202001/22/202001/22/...
# Country/Region     Mainland ChinaMainland ChinaMainland ChinaMain...
# Last Update        1/22/2020 17:001/22/2020 17:001/22/2020 17:001...
# Confirmed                                              26252051758.0
# Deaths                                                   624013017.0
# Recovered                                              15450237912.0
# dtype: object

# %%
cases_df.drop(['SNo','ObservationDate','Country/Region','Last Update'],inplace=True)
#Dropping unnecessary columns

# %%
cases_df
#Number of case types and their Total
# Out:
# Confirmed    26252051758.0
# Deaths         624013017.0
# Recovered    15450237912.0
# dtype: object

# %%
my_data = [2.62521e+10,1.54502e+10,6.24013e+08]
my_labels = 'Confirmed','Recovered', 'Deaths'
my_explode = (0,0,1.5)
my_colors = ['lightsteelblue','lightpink','grey']
fig1, ax1 = plt.subplots(figsize=(13,8))
plt.pie(my_data,labels=my_labels,autopct= '%1.1f%%', startangle = 15 , shadow=True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
#PIE chart visualization

# %%
plt.rcParams['figure.figsize'] = (60,35)
#giving figure size

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df[['Country/Region','Confirmed']].groupby(['Country/Region']).mean().sort_values(by='Confirmed').plot.bar(color='purple')
plt.show()
#We can also use the groupby function to sort values in an ascending order based on the x-axis,y-axis, and its keys
#Below we get a clear picture of countries in an increasing order based on their confirmed level of cases.
#Turkey has high level of confirmed cases compared to other countries.
#Also some countries data are not updated or shared, we need to use updated data for new actual graphs

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df[['Country/Region','Recovered']].groupby(['Country/Region']).mean().sort_values(by='Recovered').plot.bar(color='purple')
plt.show()
#We can also use the groupby function to sort values in an ascending order based on the x-axis,y-axis, and its keys
#Below we get a clear picture of countries in an increasing order based on their Recovered level of cases.
#Turkey has high level of Recovered cases compared to other countries.
#Also some countries data are not updated or shared, we need to use updated data for new actual graphs

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df[['Country/Region','Deaths']].groupby(['Country/Region']).mean().sort_values(by='Deaths').plot.bar(color='purple')
plt.show()
#We can also use the groupby function to sort values in an ascending order based on the x-axis,y-axis, and its keys
#Below we get a clear picture of countries in an increasing order based on their Deaths level of cases.
#Iran has high level of Deaths cases compared to other countries.
#Also some countries data are not updated or shared, we need to use updated data for new actual graphs

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
plt.figure(figsize=(60,35))
plt.xticks(rotation=90)
sns.barplot(x='Country/Region',y='Recovered', color='teal', data=df)
#The visualization below shows us that the high number of confirmed cases are found in Turkey followed by Argentina.
# Out:
# <AxesSubplot:xlabel='Country/Region', ylabel='Recovered'>

# %%
plt.figure(figsize=(60,35))
plt.xticks(rotation=90)
sns.barplot(x='Country/Region',y='Confirmed', color='teal', data=df)
#The visualization below shows us that the high number of Recovered cases are found in Turkey followed by Argentina.
# Out:
# <AxesSubplot:xlabel='Country/Region', ylabel='Confirmed'>

# %%
plt.figure(figsize=(60,35))
plt.xticks(rotation=90)
sns.barplot(x='Country/Region',y='Deaths', color='teal', data=df)
#The visualization below shows us that the high number of Deaths cases are found in Iran followed by Argentina.
# Out:
# <AxesSubplot:xlabel='Country/Region', ylabel='Deaths'>

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
import pandas as pd

df=pd.read_csv('resources/covid_19_data.csv');

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df.drop(['SNo','ObservationDate','Last Update'], axis=1, inplace=True)
#We have dropped some column

# %%
df.head(5)
# Out:
#   Province/State  Country/Region  Confirmed  Deaths  Recovered
# 0          Anhui  Mainland China        1.0     0.0        0.0
# 1        Beijing  Mainland China       14.0     0.0        0.0
# 2      Chongqing  Mainland China        6.0     0.0        0.0
# 3         Fujian  Mainland China        1.0     0.0        0.0
# 4          Gansu  Mainland China        0.0     0.0        0.0

# %%
df.set_index('Country/Region')
#Setting index as Country/Region name
# Out:
#                    Province/State  Confirmed  Deaths  Recovered
# Country/Region
# Mainland China              Anhui        1.0     0.0        0.0
# Mainland China            Beijing       14.0     0.0        0.0
# Mainland China          Chongqing        6.0     0.0        0.0
# Mainland China             Fujian        1.0     0.0        0.0
# Mainland China              Gansu        0.0     0.0        0.0
# ...                           ...        ...     ...        ...
# Ukraine         Zaporizhia Oblast   102641.0  2335.0    95289.0
# Netherlands               Zeeland    29147.0   245.0        0.0
# Mainland China           Zhejiang     1364.0     1.0     1324.0
# Ukraine           Zhytomyr Oblast    87550.0  1738.0    83790.0
# Netherlands          Zuid-Holland   391559.0  4252.0        0.0
#
# [306429 rows x 4 columns]

# %%
df.head(5)
# Out:
#   Province/State  Country/Region  Confirmed  Deaths  Recovered
# 0          Anhui  Mainland China        1.0     0.0        0.0
# 1        Beijing  Mainland China       14.0     0.0        0.0
# 2      Chongqing  Mainland China        6.0     0.0        0.0
# 3         Fujian  Mainland China        1.0     0.0        0.0
# 4          Gansu  Mainland China        0.0     0.0        0.0

# %%
df.set_index('Country/Region')
#Setting index as Country/Region name
#df.plot.barh(stacked=True,figsize=(60,35))
#Stacked bar plot
# Out:
#                    Province/State  Confirmed  Deaths  Recovered
# Country/Region
# Mainland China              Anhui        1.0     0.0        0.0
# Mainland China            Beijing       14.0     0.0        0.0
# Mainland China          Chongqing        6.0     0.0        0.0
# Mainland China             Fujian        1.0     0.0        0.0
# Mainland China              Gansu        0.0     0.0        0.0
# ...                           ...        ...     ...        ...
# Ukraine         Zaporizhia Oblast   102641.0  2335.0    95289.0
# Netherlands               Zeeland    29147.0   245.0        0.0
# Mainland China           Zhejiang     1364.0     1.0     1324.0
# Ukraine           Zhytomyr Oblast    87550.0  1738.0    83790.0
# Netherlands          Zuid-Holland   391559.0  4252.0        0.0
#
# [306429 rows x 4 columns]

# %%
df.plot.barh(stacked=True,figsize=(60,35))
# Stacked bar plot

# %%
#df1 = df[['Confirmed','Deaths']]
#df1.plot.barh(color={"Confirmed":"aquamarine" , "Deaths":"purple"}, figsize=(60,35))
#bar plot for Confirmed and Deaths

# %%
#df1 = df[['Recovered','Deaths']]
#df1.plot.barh(color={"Confirmed":"aquamarine" , "Deaths":"purple"}, figsize=(60,35))
#bar plot for Recovered and Deaths

# %%
#The above code crashes the RAM of Google Colab, huge data, working on it, we can take a bit of data fram from the data set and plot it with above code.
#More Data Analysis in next Notebook.
#Thanks for Reading
