# %% [markdown]
# # import libaries
# - Seaborn automatically installs these libraries
# - numpy
# - scipy
# - pandas
# - matplotlib

# %%
# import libraries
import seaborn as sns 
import matplotlib.pyplot as plt
# load dataset 
phool = sns.load_dataset("iris")
phool
# draw a line plot 
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
plt.show()

# %%
# import libraries
import seaborn as sns 
import matplotlib.pyplot as plt
# load dataset 
phool = sns.load_dataset("iris")
phool
# draw a line plot 
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
plt.title("Flower plot")
plt.show()

# %%
##  Adding limits

# %%
# import libraries
import seaborn as sns 
import matplotlib.pyplot as plt
# load dataset 
phool = sns.load_dataset("iris")
phool
# draw a line plot 
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
plt.title("Flower plot")
plt.xlim(2)
plt.ylim(1)
plt.show()

# %% [markdown]
# ## set styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %% [markdown]
# ## Assignment

# %%
# import libraries
import seaborn as sns 
import matplotlib.pyplot as plt                       
# load dataset 
phool = sns.load_dataset("iris")
phool
# draw a line plot 
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool)
plt.title("Flower plot")
sns.set_style("dark")
sns.set_style(style=None, rc=None) 
plt.show()

# %%
# Size of figure

# %%
# import libraries
import seaborn as sns 
# load dataset 
phool1 = sns.load_dataset("iris")
#change fig
plt.figure(figsize=(10,8))
# draw a line plot 
sns.lineplot(x="sepal_length", y= "sepal_width", data=phool1)
plt.title("Flower plot")
plt.show()
